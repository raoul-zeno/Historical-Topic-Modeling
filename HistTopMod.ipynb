# %% [markdown]
# ***This is a Jupyter Notebook for the project ```Historical Topic Modelling```***

# %% [markdown]
# Let's first create a new clean environment! If prompted to select the environment, click yes.

# %%
# !python -m venv HistTopMod

# %% [markdown]
# Next, let's first install ipykernel, so that the virtual environment can be used as a kernel:
# Depending on your internet connection, this might take a while.

# %%
# !HistTopMod\Scripts\python -m pip install notebook ipykernel

# %% [markdown]
# Now let's register the Virtual Environment with Jupyter

# %%
# !HistTopMod\Scripts\python -m ipykernel install --user --name=HistTopMod --display-name "Python (HistTopMod)"

# %% [markdown]
# **This step is crucial, and involves you changing the kernel manually inside your IDE.**

# %% [markdown]
# 1. Select the current kernel (usually base)
# 2. Choose "Select Another Kernel"
# 3. Choose "Python Environments"
# 4. Choose the newly created HistTopMod kernel

# %% [markdown]
# Now we are all set with our clean virtual environment!

# %% [markdown]
# ***Get all required packages***

# %% [markdown]
# A requirements.txt file is provided here:
#
# ``https://github.com/raoul-zeno/Historical-Topic-Modeling/blob/main/requirements.txt``
#
# You can either copy and paste the requirements.txt file into this directory, or alternatively run the code below to do the fetch automatically.

# %%
import requests
import os

gitlab_req_url = "https://raw.githubusercontent.com/raoul-zeno/Historical-Topic-Modeling/refs/heads/main/requirements.txt"

try:
    response = requests.get(gitlab_req_url)
    response.raise_for_status()

    with open ("requirements.txt", "w") as file:
        file.write(response.text)
    
    print("requirements.txt was fetched and saved to the directory!")

except requests.exceptions.RequestException as e:
    print(f"Failed to fetch the file: {e}")

# %% [markdown]
# To install all the necessary libraries from requirements.txt run the following code:
#
# As quite a few libraries are needed due to the complexity of the models, this might take a while, depending on your internet connection. Don't worry, as long as you keep working in this directory, this step only needs to be done once.

# %%
import subprocess

try:
    subprocess.check_call(["pip", "install", "-r", "requirements.txt"])
    print("All packages installed successfully!")

except subprocess.CalledProcessError as e:
    print(f"An error occured: {e}")

# %% [markdown]
# Great! So we are all set for some topic modelling!

# %% [markdown]
# Next, let's create a directory, to store our source XML-Files in!

# %%
# !mkdir source_files

# %% [markdown]
# Please copy all the source files (in XML-Format) into this directory.

# %% [markdown]
# This next step does three things:
# 1. An SQL-database is created inside this directory
# 2. Some key information and the texts of each XML-File is extracted
# 3. This data is added to the SQL-Database
#
# Depending on the size of the corpus this might take a while, as it loops over every individual XML-File and extracts the data.

# %%
import pandas as pd
import pprint as pp
import os
import xml.etree.ElementTree as ET
import sqlite3

xml_directory = r"./source_files/"

data = []

con = sqlite3.connect("Database.db")
cur = con.cursor()

def extract_text(text_element):
    text_content = []

    def recursive_extract(text_elem):
        if text_elem.text:
            text_content.append(text_elem.text)
        for child in text_elem:
            recursive_extract(child)
            if child.tail:
                text_content.append(child.tail)

    recursive_extract(text_element)
    
    return " ".join(text_content)


for file_name in os.listdir(xml_directory):
    if file_name.endswith(".xml"):
        file_path = os.path.join(xml_directory, file_name)


        tree = ET.parse(file_path)
        root = tree.getroot()
        ns = {"ns0":"http://www.tei-c.org/ns/1.0"}

        main_title = root.findtext('.//ns0:title[@type="main"]', namespaces=ns)
        sub_title = root.findtext('.//ns0:title[@type="sub"]', namespaces=ns)
        volume_title = root.findtext('.//ns0:title[@type="volume"]', namespaces=ns)
        class_main = root.findtext(".//ns0:classCode[@scheme='https://www.deutschestextarchiv.de/doku/klassifikation#dwds1main']", namespaces=ns)
        class_sub = root.findtext(".//ns0:classCode[@scheme='https://www.deutschestextarchiv.de/doku/klassifikation#dwds1sub']", namespaces=ns)
        author_surname = root.findtext(".//ns0:surname", namespaces=ns)
        author_forename = root.findtext(".//ns0:forename", namespaces=ns)
        author = f"{author_surname}, {author_forename}"
        publication_date_str = root.findtext(".//ns0:sourceDesc/ns0:biblFull/ns0:publicationStmt/ns0:date[@type='publication']", namespaces=ns)
        language = root.findtext(".//ns0:language", namespaces=ns)
        text_element = root.find(".//ns0:text", namespaces=ns)
        plain_text = extract_text(text_element)

        data.append({
            "main_title": main_title,
            "sub_title": sub_title,
            "volume_title": volume_title,
            "author": author,
            "publication_date": publication_date_str,
            "class_main": class_main,
            "class_sub": class_sub,
            "language": language,
            "text": plain_text
        })

df = pd.DataFrame(data)

df.to_sql("my_data", con, index=True, if_exists="replace")

# %% [markdown]
# There is an issue, where in the database the index is called index (an SQL-command). So let's change that.

# %%
import sqlite3

con = sqlite3.connect("Database.db")
cur = con.cursor()

cur.execute("ALTER TABLE my_data RENAME COLUMN 'index' TO text_index;")

print("Renamed index to text_index")

# %% [markdown]
# The groundwork for the modelling is now done. Let's restart the kernel to clear memory. Everything done before (creation of database, installing libraries from requirements.txt) will stay.

# %% [markdown]
# **Text Preprocessing**
# In this section, the plain texts in the database will be preprocessed for Machine Learning purposes. For this, we use regex. The preprocessed texts will be added automatically to the database.

# %% [markdown]
# Let's first create a new column called preprocessed_text

# %%
import sqlite3

con = sqlite3.connect("Database.db")
cur = con.cursor()

cur.execute("ALTER TABLE my_data ADD COLUMN preprocessed_text text")

# %% [markdown]
# Then next, we do the preprocessing and add it to the newly created column.

# %%
import pandas as pd
import unicodedata
import re
import sqlite3
import time

con = sqlite3.connect("Database.db")
cur = con.cursor()

def preprocess_text(text):
    #lowercase the text
    result_text = text.lower()

    #normalize text
    result_text = unicodedata.normalize("NFD", result_text)

    #take out two-letter and single-letter words (experimental)
    result_text = re.sub(r"\b\w{1, 2}\b", "", result_text)
    result_text = re.sub(r"\s+", " ", result_text).strip()

    #remove diaresis
    result_text = re.sub(r"(?<=\w)\u0364", "e", result_text)
    result_text = re.sub(r"o\u0308", "oe", result_text)
    result_text = re.sub(r"a\u0308", "ae", result_text)
    result_text = re.sub(r"u\u0308", "ue", result_text)

    #removing long s
    result_text = re.sub(r"\u017F", "s", result_text)

    #removing round r
    result_text = re.sub(r"\uA75B", "r", result_text)

    #removing ligatures
    result_text = re.sub(r"\u00E6", "ae", result_text)
    result_text = re.sub(r"\u0153", "oe", result_text)

    #removing abbreviations
    result_text = re.sub(r"m\u0303", "m", result_text)
    result_text = re.sub(r"n\u0303", "d", result_text)

    #remove unneeded special characters
    pattern = r"[/;:,()\[\]\"\"*]"
    result_text = re.sub(pattern, "", result_text)

    #remove \n and -\n
    result_text = re.sub(r'- \n', "", result_text)
    result_text = re.sub(r'\n', '', result_text)

    #remove multiple spaces
    result_text = re.sub(" +", " ", result_text)

    #remove special characters
    result_text = re.sub(r"[^a-zA-Z\s]", "", result_text)

    #cleanup double spaces due to removal of single letters and digits
    result_text = re.sub(r"\s{2,}", " ", result_text).strip()

    return result_text
    
def add_pp_texts_to_database():
    number_of_entries = cur.execute("SELECT COUNT(*) FROM my_data").fetchone()
    for i in range(number_of_entries[0]):
        start = time.time()
        example_textObj = cur.execute("SELECT text FROM my_data WHERE text_index=?", (i,))
        example_text = example_textObj.fetchone()
        result_text = preprocess_text(example_text[0])
        cur.execute("UPDATE my_data SET preprocessed_text=? WHERE text_index=?", (result_text, i,))
        end = time.time()
        print(f"ID {i} has taken {end - start} seconds")
    con.commit()

add_pp_texts_to_database()
# Out:
# ID 0 has taken 0.02062082290649414 seconds
# ID 1 has taken 0.030745744705200195 seconds
# ID 2 has taken 0.03801369667053223 seconds
# ID 3 has taken 0.01793193817138672 seconds
# ID 4 has taken 0.01477503776550293 seconds
# ID 5 has taken 0.08770871162414551 seconds
# ID 6 has taken 0.014225959777832031 seconds
# ID 7 has taken 0.03520989418029785 seconds
# ID 8 has taken 0.054923057556152344 seconds
# ID 9 has taken 0.020576000213623047 seconds
# ID 10 has taken 0.0 seconds
# ID 11 has taken 0.012901067733764648 seconds
# ID 12 has taken 0.01747608184814453 seconds
# ID 13 has taken 0.007758140563964844 seconds
# ID 14 has taken 0.017307043075561523 seconds
# ID 15 has taken 0.016184568405151367 seconds
# ID 16 has taken 0.00859379768371582 seconds
# ID 17 has taken 0.0 seconds
# ID 18 has taken 0.007204294204711914 seconds
# ID 19 has taken 0.05232715606689453 seconds
# ID 20 has taken 0.03126859664916992 seconds
# ID 21 has taken 0.007688760757446289 seconds
# ID 22 has taken 0.007014751434326172 seconds
# ID 23 has taken 0.0 seconds
# ID 24 has taken 0.04111146926879883 seconds
# ID 25 has taken 0.03321123123168945 seconds
# ID 26 has taken 0.01950979232788086 seconds
# ID 27 has taken 0.045156240463256836 seconds
# ID 28 has taken 0.01599860191345215 seconds
# ID 29 has taken 0.04730367660522461 seconds
# ID 30 has taken 0.02967238426208496 seconds
# ID 31 has taken 0.012505531311035156 seconds
# ID 32 has taken 0.015008687973022461 seconds
# ID 33 has taken 0.0 seconds
# ID 34 has taken 0.0 seconds
# ID 35 has taken 0.0 seconds
# ID 36 has taken 0.01577138900756836 seconds
# ID 37 has taken 0.04730343818664551 seconds
# ID 38 has taken 0.016558408737182617 seconds
# ID 39 has taken 0.08998441696166992 seconds
# ID 40 has taken 0.05763840675354004 seconds
# ID 41 has taken 0.016176700592041016 seconds
# ID 42 has taken 0.07163763046264648 seconds
# ID 43 has taken 0.037546634674072266 seconds
# ID 44 has taken 0.05156207084655762 seconds
# ID 45 has taken 0.03130745887756348 seconds
# ID 46 has taken 0.015628337860107422 seconds
# ID 47 has taken 0.03212928771972656 seconds
# ID 48 has taken 0.022449970245361328 seconds
# ID 49 has taken 0.0481715202331543 seconds
# ID 50 has taken 0.06234574317932129 seconds
# ID 51 has taken 0.04406166076660156 seconds
# ID 52 has taken 0.053869009017944336 seconds
# ID 53 has taken 0.0 seconds
# ID 54 has taken 0.04745626449584961 seconds
# ID 55 has taken 0.08136272430419922 seconds
# ID 56 has taken 0.09204769134521484 seconds
# ID 57 has taken 0.0690011978149414 seconds
# ID 58 has taken 0.0 seconds
# ID 59 has taken 0.03106093406677246 seconds
# ID 60 has taken 0.08326840400695801 seconds
# ID 61 has taken 0.0 seconds
# ID 62 has taken 0.053910255432128906 seconds
# ID 63 has taken 0.07220458984375 seconds
# ID 64 has taken 0.016394376754760742 seconds
# ID 65 has taken 0.02457261085510254 seconds
# ID 66 has taken 0.02508854866027832 seconds
# ID 67 has taken 0.024678707122802734 seconds
# ID 68 has taken 0.04082536697387695 seconds
# ID 69 has taken 0.051407814025878906 seconds
# ID 70 has taken 0.04957413673400879 seconds
# ID 71 has taken 0.016572237014770508 seconds
# ID 72 has taken 0.008668661117553711 seconds
# ID 73 has taken 0.041379451751708984 seconds
# ID 74 has taken 0.030704259872436523 seconds
# ID 75 has taken 0.011184930801391602 seconds
# ID 76 has taken 0.02435302734375 seconds
# ID 77 has taken 0.010619640350341797 seconds
# ID 78 has taken 0.010144233703613281 seconds
# ID 79 has taken 0.004883289337158203 seconds
# ID 80 has taken 0.04935288429260254 seconds
# ID 81 has taken 0.008456945419311523 seconds
# ID 82 has taken 0.033904314041137695 seconds
# ID 83 has taken 0.043903350830078125 seconds
# ID 84 has taken 0.04768180847167969 seconds
# ID 85 has taken 0.024070024490356445 seconds
# ID 86 has taken 0.024962663650512695 seconds
# ID 87 has taken 0.024955034255981445 seconds
# ID 88 has taken 0.025177478790283203 seconds
# ID 89 has taken 0.025014638900756836 seconds
# ID 90 has taken 0.008083105087280273 seconds
# ID 91 has taken 0.050197601318359375 seconds
# ID 92 has taken 0.03690338134765625 seconds
# ID 93 has taken 0.021210908889770508 seconds
# ID 94 has taken 0.015954256057739258 seconds
# ID 95 has taken 0.042348384857177734 seconds
# ID 96 has taken 0.01798725128173828 seconds
# ID 97 has taken 0.07401227951049805 seconds
# ID 98 has taken 0.04181480407714844 seconds
# ID 99 has taken 0.025569677352905273 seconds
# ID 100 has taken 0.015495538711547852 seconds
# ID 101 has taken 0.05875420570373535 seconds
# ID 102 has taken 0.016520261764526367 seconds
# ID 103 has taken 0.03260159492492676 seconds
# ID 104 has taken 0.018197298049926758 seconds
# ID 105 has taken 0.0270845890045166 seconds
# ID 106 has taken 0.06719040870666504 seconds
# ID 107 has taken 0.03166055679321289 seconds
# ID 108 has taken 0.03127479553222656 seconds
# ID 109 has taken 0.026004552841186523 seconds
# ID 110 has taken 0.07870101928710938 seconds
# ID 111 has taken 0.034967899322509766 seconds
# ID 112 has taken 0.07911539077758789 seconds
# ID 113 has taken 0.05745410919189453 seconds
# ID 114 has taken 0.03116917610168457 seconds
# ID 115 has taken 0.03372073173522949 seconds
# ID 116 has taken 0.018903255462646484 seconds
# ID 117 has taken 0.0058367252349853516 seconds
# ID 118 has taken 0.019954919815063477 seconds
# ID 119 has taken 0.06848382949829102 seconds
# ID 120 has taken 0.047919511795043945 seconds
# ID 121 has taken 0.01574420928955078 seconds
# ID 122 has taken 0.05648350715637207 seconds
# ID 123 has taken 0.017485857009887695 seconds
# ID 124 has taken 0.014381170272827148 seconds
# ID 125 has taken 0.015117168426513672 seconds
# ID 126 has taken 0.07075977325439453 seconds
# ID 127 has taken 0.006477832794189453 seconds
# ID 128 has taken 0.02531743049621582 seconds
# ID 129 has taken 0.05962657928466797 seconds
# ID 130 has taken 0.0 seconds
# ID 131 has taken 0.013509273529052734 seconds
# ID 132 has taken 0.03126215934753418 seconds
# ID 133 has taken 0.025094985961914062 seconds
# ID 134 has taken 0.01580977439880371 seconds
# ID 135 has taken 0.01563572883605957 seconds
# ID 136 has taken 0.046875715255737305 seconds
# ID 137 has taken 0.01694464683532715 seconds
# ID 138 has taken 0.013350486755371094 seconds
# ID 139 has taken 0.012085437774658203 seconds
# ID 140 has taken 0.03098750114440918 seconds
# ID 141 has taken 0.03125309944152832 seconds
# ID 142 has taken 0.023590564727783203 seconds
# ID 143 has taken 0.02032184600830078 seconds
# ID 144 has taken 0.028061866760253906 seconds
# ID 145 has taken 0.0027599334716796875 seconds
# ID 146 has taken 0.030030488967895508 seconds
# ID 147 has taken 0.016080141067504883 seconds
# ID 148 has taken 0.018483638763427734 seconds
# ID 149 has taken 0.04594850540161133 seconds
# ID 150 has taken 0.03183412551879883 seconds
# ID 151 has taken 0.03151750564575195 seconds
# ID 152 has taken 0.010037899017333984 seconds
# ID 153 has taken 0.030930757522583008 seconds
# ID 154 has taken 0.06151318550109863 seconds
# ID 155 has taken 0.009757280349731445 seconds
# ID 156 has taken 0.026570796966552734 seconds
# ID 157 has taken 0.027242422103881836 seconds
# ID 158 has taken 0.010695219039916992 seconds
# ID 159 has taken 0.0241544246673584 seconds
# ID 160 has taken 0.0248873233795166 seconds
# ID 161 has taken 0.0 seconds
# ID 162 has taken 0.050997018814086914 seconds
# ID 163 has taken 0.013840675354003906 seconds
# ID 164 has taken 0.020099878311157227 seconds
# ID 165 has taken 0.01668572425842285 seconds
# ID 166 has taken 0.0 seconds
# ID 167 has taken 0.02885293960571289 seconds
# ID 168 has taken 0.00782322883605957 seconds
# ID 169 has taken 0.0 seconds
# ID 170 has taken 0.015022039413452148 seconds
# ID 171 has taken 0.015642881393432617 seconds
# ID 172 has taken 0.0 seconds
# ID 173 has taken 0.02153325080871582 seconds
# ID 174 has taken 0.017388343811035156 seconds
# ID 175 has taken 0.015625953674316406 seconds
# ID 176 has taken 0.03173065185546875 seconds
# ID 177 has taken 0.04740476608276367 seconds
# ID 178 has taken 0.03548264503479004 seconds
# ID 179 has taken 0.031032085418701172 seconds
# ID 180 has taken 0.01601099967956543 seconds
# ID 181 has taken 0.013597488403320312 seconds
# ID 182 has taken 0.017757892608642578 seconds
# ID 183 has taken 0.015625953674316406 seconds
# ID 184 has taken 0.031677961349487305 seconds
# ID 185 has taken 0.03654122352600098 seconds
# ID 186 has taken 0.031475067138671875 seconds
# ID 187 has taken 0.032035112380981445 seconds
# ID 188 has taken 0.033429622650146484 seconds
# ID 189 has taken 0.02715587615966797 seconds
# ID 190 has taken 0.015634536743164062 seconds
# ID 191 has taken 0.016120433807373047 seconds
# ID 192 has taken 0.005515336990356445 seconds
# ID 193 has taken 0.010513544082641602 seconds
# ID 194 has taken 0.0 seconds
# ID 195 has taken 0.015958309173583984 seconds
# ID 196 has taken 0.051448822021484375 seconds
# ID 197 has taken 0.02335500717163086 seconds
# ID 198 has taken 0.008551597595214844 seconds
# ID 199 has taken 0.011583805084228516 seconds
# ID 200 has taken 0.01394200325012207 seconds
# ID 201 has taken 0.02217864990234375 seconds
# ID 202 has taken 0.014008283615112305 seconds
# ID 203 has taken 0.015635967254638672 seconds
# ID 204 has taken 0.03165936470031738 seconds
# ID 205 has taken 0.034158945083618164 seconds
# ID 206 has taken 0.01938629150390625 seconds
# ID 207 has taken 0.0322422981262207 seconds
# ID 208 has taken 0.0 seconds
# ID 209 has taken 0.04538917541503906 seconds
# ID 210 has taken 0.030193567276000977 seconds
# ID 211 has taken 0.048803091049194336 seconds
# ID 212 has taken 0.09196972846984863 seconds
# ID 213 has taken 0.030096769332885742 seconds
# ID 214 has taken 0.04015803337097168 seconds
# ID 215 has taken 0.014691591262817383 seconds
# ID 216 has taken 0.016811132431030273 seconds
# ID 217 has taken 0.030526161193847656 seconds
# ID 218 has taken 0.019420385360717773 seconds
# ID 219 has taken 0.031707763671875 seconds
# ID 220 has taken 0.055815935134887695 seconds
# ID 221 has taken 0.07244253158569336 seconds
# ID 222 has taken 0.04158663749694824 seconds
# ID 223 has taken 0.017414331436157227 seconds
# ID 224 has taken 0.014528036117553711 seconds
# ID 225 has taken 0.0482172966003418 seconds
# ID 226 has taken 0.030569076538085938 seconds
# ID 227 has taken 0.013196229934692383 seconds
# ID 228 has taken 0.02998661994934082 seconds
# ID 229 has taken 0.021903038024902344 seconds
# ID 230 has taken 0.015691280364990234 seconds
# ID 231 has taken 0.03313612937927246 seconds
# ID 232 has taken 0.007159233093261719 seconds
# ID 233 has taken 0.031298160552978516 seconds
# ID 234 has taken 0.0 seconds
# ID 235 has taken 0.015649795532226562 seconds
# ID 236 has taken 0.04550004005432129 seconds
# ID 237 has taken 0.023662090301513672 seconds
# ID 238 has taken 0.0362095832824707 seconds
# ID 239 has taken 0.06983542442321777 seconds
# ID 240 has taken 0.015626192092895508 seconds
# ID 241 has taken 0.04742884635925293 seconds
# ID 242 has taken 0.014307737350463867 seconds
# ID 243 has taken 0.039777278900146484 seconds
# ID 244 has taken 0.05103802680969238 seconds
# ID 245 has taken 0.024858474731445312 seconds
# ID 246 has taken 0.008871793746948242 seconds
# ID 247 has taken 0.005511760711669922 seconds
# ID 248 has taken 0.03500008583068848 seconds
# ID 249 has taken 0.013111591339111328 seconds
# ID 250 has taken 0.018135547637939453 seconds
# ID 251 has taken 0.05835437774658203 seconds
# ID 252 has taken 0.017331600189208984 seconds
# ID 253 has taken 0.019519805908203125 seconds
# ID 254 has taken 0.013927936553955078 seconds
# ID 255 has taken 0.015593767166137695 seconds
# ID 256 has taken 0.0312650203704834 seconds
# ID 257 has taken 0.05312800407409668 seconds
# ID 258 has taken 0.017048358917236328 seconds
# ID 259 has taken 0.031153202056884766 seconds
# ID 260 has taken 0.01811814308166504 seconds
# ID 261 has taken 0.013784646987915039 seconds
# ID 262 has taken 0.021685123443603516 seconds
# ID 263 has taken 0.019971847534179688 seconds
# ID 264 has taken 0.016742706298828125 seconds
# ID 265 has taken 0.04073309898376465 seconds
# ID 266 has taken 0.009769201278686523 seconds
# ID 267 has taken 0.020580530166625977 seconds
# ID 268 has taken 0.03154134750366211 seconds
# ID 269 has taken 0.0 seconds
# ID 270 has taken 0.015011310577392578 seconds
# ID 271 has taken 0.031673431396484375 seconds
# ID 272 has taken 0.0156404972076416 seconds
# ID 273 has taken 0.03337860107421875 seconds
# ID 274 has taken 0.04761695861816406 seconds
# ID 275 has taken 0.01572871208190918 seconds
# ID 276 has taken 0.04045295715332031 seconds
# ID 277 has taken 0.06356096267700195 seconds
# ID 278 has taken 0.04195713996887207 seconds
# ID 279 has taken 0.015014410018920898 seconds
# ID 280 has taken 0.04919600486755371 seconds
# ID 281 has taken 0.04657769203186035 seconds
# ID 282 has taken 0.02744770050048828 seconds
# ID 283 has taken 0.0 seconds
# ID 284 has taken 0.015509843826293945 seconds
# ID 285 has taken 0.0408933162689209 seconds
# ID 286 has taken 0.024264812469482422 seconds
# ID 287 has taken 0.02948904037475586 seconds
# ID 288 has taken 0.01581263542175293 seconds
# ID 289 has taken 0.03186917304992676 seconds
# ID 290 has taken 0.0 seconds
# ID 291 has taken 0.0944371223449707 seconds
# ID 292 has taken 0.04184913635253906 seconds
# ID 293 has taken 0.02511000633239746 seconds
# ID 294 has taken 0.016640663146972656 seconds
# ID 295 has taken 0.03865337371826172 seconds
# ID 296 has taken 0.047371625900268555 seconds
# ID 297 has taken 0.02191305160522461 seconds
# ID 298 has taken 0.03834939002990723 seconds
# ID 299 has taken 0.0230410099029541 seconds
# ID 300 has taken 0.008509397506713867 seconds
# ID 301 has taken 0.05532383918762207 seconds
# ID 302 has taken 0.05377531051635742 seconds
# ID 303 has taken 0.03132748603820801 seconds
# ID 304 has taken 0.03414201736450195 seconds
# ID 305 has taken 0.011930704116821289 seconds
# ID 306 has taken 0.03131532669067383 seconds
# ID 307 has taken 0.037424325942993164 seconds
# ID 308 has taken 0.0 seconds
# ID 309 has taken 0.037323951721191406 seconds
# ID 310 has taken 0.03251791000366211 seconds
# ID 311 has taken 0.02651190757751465 seconds
# ID 312 has taken 0.017641067504882812 seconds
# ID 313 has taken 0.06018400192260742 seconds
# ID 314 has taken 0.02530837059020996 seconds
# ID 315 has taken 0.03318428993225098 seconds
# ID 316 has taken 0.07332801818847656 seconds
# ID 317 has taken 0.041815757751464844 seconds
# ID 318 has taken 0.029848098754882812 seconds
# ID 319 has taken 0.029923677444458008 seconds
# ID 320 has taken 0.021690845489501953 seconds
# ID 321 has taken 0.05724191665649414 seconds
# ID 322 has taken 0.025021791458129883 seconds
# ID 323 has taken 0.01312708854675293 seconds
# ID 324 has taken 0.03306913375854492 seconds
# ID 325 has taken 0.05771827697753906 seconds
# ID 326 has taken 0.050219058990478516 seconds
# ID 327 has taken 0.008222341537475586 seconds
# ID 328 has taken 0.03124713897705078 seconds
# ID 329 has taken 0.009772539138793945 seconds
# ID 330 has taken 0.049971818923950195 seconds
# ID 331 has taken 0.04158663749694824 seconds
# ID 332 has taken 0.07636475563049316 seconds
# ID 333 has taken 0.018778324127197266 seconds
# ID 334 has taken 0.03761744499206543 seconds
# ID 335 has taken 0.0 seconds
# ID 336 has taken 0.008878946304321289 seconds
# ID 337 has taken 0.0008366107940673828 seconds
# ID 338 has taken 0.0057561397552490234 seconds
# ID 339 has taken 0.0013191699981689453 seconds
# ID 340 has taken 0.0 seconds
# ID 341 has taken 0.008454084396362305 seconds
# ID 342 has taken 0.0 seconds
# ID 343 has taken 0.0 seconds
# ID 344 has taken 0.008159160614013672 seconds
# ID 345 has taken 0.0 seconds
# ID 346 has taken 0.007771730422973633 seconds
# ID 347 has taken 0.0001590251922607422 seconds
# ID 348 has taken 0.0 seconds
# ID 349 has taken 0.008472442626953125 seconds
# ID 350 has taken 0.0006387233734130859 seconds
# ID 351 has taken 0.0 seconds
# ID 352 has taken 0.0 seconds
# ID 353 has taken 0.009674549102783203 seconds
# ID 354 has taken 0.002077341079711914 seconds
# ID 355 has taken 0.004228115081787109 seconds
# ID 356 has taken 0.003003358840942383 seconds
# ID 357 has taken 0.002009868621826172 seconds
# ID 358 has taken 0.0004181861877441406 seconds
# ID 359 has taken 0.0021533966064453125 seconds
# ID 360 has taken 0.0030019283294677734 seconds
# ID 361 has taken 0.0030863285064697266 seconds
# ID 362 has taken 0.0032427310943603516 seconds
# ID 363 has taken 0.0 seconds
# ID 364 has taken 0.03283572196960449 seconds
# ID 365 has taken 0.008786678314208984 seconds
# ID 366 has taken 0.0 seconds
# ID 367 has taken 0.0 seconds
# ID 368 has taken 0.007631063461303711 seconds
# ID 369 has taken 0.0 seconds
# ID 370 has taken 0.0 seconds
# ID 371 has taken 0.009093761444091797 seconds
# ID 372 has taken 0.0 seconds
# ID 373 has taken 0.01589202880859375 seconds
# ID 374 has taken 0.009348154067993164 seconds
# ID 375 has taken 0.007270097732543945 seconds
# ID 376 has taken 0.010291099548339844 seconds
# ID 377 has taken 0.0008640289306640625 seconds
# ID 378 has taken 0.006535530090332031 seconds
# ID 379 has taken 0.0013096332550048828 seconds
# ID 380 has taken 0.005624532699584961 seconds
# ID 381 has taken 0.0 seconds
# ID 382 has taken 0.0 seconds
# ID 383 has taken 0.00810694694519043 seconds
# ID 384 has taken 0.0 seconds
# ID 385 has taken 0.0 seconds
# ID 386 has taken 0.0 seconds
# ID 387 has taken 0.008167028427124023 seconds
# ID 388 has taken 0.0 seconds
# ID 389 has taken 0.007482051849365234 seconds
# ID 390 has taken 0.0 seconds
# ID 391 has taken 0.0 seconds
# ID 392 has taken 0.0011835098266601562 seconds
# ID 393 has taken 0.0 seconds
# ID 394 has taken 0.008199453353881836 seconds
# ID 395 has taken 0.0 seconds
# ID 396 has taken 0.00848078727722168 seconds
# ID 397 has taken 0.0010020732879638672 seconds
# ID 398 has taken 0.006177425384521484 seconds
# ID 399 has taken 0.0011756420135498047 seconds
# ID 400 has taken 0.0 seconds
# ID 401 has taken 0.009020090103149414 seconds
# ID 402 has taken 0.0 seconds
# ID 403 has taken 0.007570028305053711 seconds
# ID 404 has taken 0.002962350845336914 seconds
# ID 405 has taken 0.0038406848907470703 seconds
# ID 406 has taken 0.00304412841796875 seconds
# ID 407 has taken 0.0030994415283203125 seconds
# ID 408 has taken 0.003545999526977539 seconds
# ID 409 has taken 0.002985715866088867 seconds
# ID 410 has taken 0.0029938220977783203 seconds
# ID 411 has taken 0.0010018348693847656 seconds
# ID 412 has taken 0.0023577213287353516 seconds
# ID 413 has taken 0.0 seconds
# ID 414 has taken 0.007321357727050781 seconds
# ID 415 has taken 0.0 seconds
# ID 416 has taken 0.0 seconds
# ID 417 has taken 0.008506298065185547 seconds
# ID 418 has taken 0.0 seconds
# ID 419 has taken 0.0 seconds
# ID 420 has taken 0.0018000602722167969 seconds
# ID 421 has taken 0.0 seconds
# ID 422 has taken 0.007775068283081055 seconds
# ID 423 has taken 0.0017876625061035156 seconds
# ID 424 has taken 0.006212949752807617 seconds
# ID 425 has taken 0.0023055076599121094 seconds
# ID 426 has taken 0.0 seconds
# ID 427 has taken 0.0 seconds
# ID 428 has taken 0.007474660873413086 seconds
# ID 429 has taken 0.0024089813232421875 seconds
# ID 430 has taken 0.0 seconds
# ID 431 has taken 0.0036783218383789062 seconds
# ID 432 has taken 0.003048419952392578 seconds
# ID 433 has taken 0.003214120864868164 seconds
# ID 434 has taken 0.0019693374633789062 seconds
# ID 435 has taken 0.0020303726196289062 seconds
# ID 436 has taken 0.0030083656311035156 seconds
# ID 437 has taken 0.0033380985260009766 seconds
# ID 438 has taken 0.003011465072631836 seconds
# ID 439 has taken 0.0029900074005126953 seconds
# ID 440 has taken 0.0010018348693847656 seconds
# ID 441 has taken 0.0021271705627441406 seconds
# ID 442 has taken 0.0 seconds
# ID 443 has taken 0.0064542293548583984 seconds
# ID 444 has taken 4.209324836730957 seconds
# ID 445 has taken 0.17502951622009277 seconds
# ID 446 has taken 0.5250308513641357 seconds
# ID 447 has taken 0.18577957153320312 seconds
# ID 448 has taken 0.18066811561584473 seconds
# ID 449 has taken 0.23235487937927246 seconds
# ID 450 has taken 0.09333443641662598 seconds
# ID 451 has taken 0.13173484802246094 seconds
# ID 452 has taken 0.05091428756713867 seconds
# ID 453 has taken 0.18346905708312988 seconds
# ID 454 has taken 0.006944894790649414 seconds
# ID 455 has taken 0.4160614013671875 seconds
# ID 456 has taken 0.06127810478210449 seconds
# ID 457 has taken 0.2236156463623047 seconds
# ID 458 has taken 0.22714447975158691 seconds
# ID 459 has taken 0.1921844482421875 seconds
# ID 460 has taken 0.18740391731262207 seconds
# ID 461 has taken 0.21680974960327148 seconds
# ID 462 has taken 0.05168509483337402 seconds
# ID 463 has taken 0.06480860710144043 seconds
# ID 464 has taken 0.1083991527557373 seconds
# ID 465 has taken 0.03475546836853027 seconds
# ID 466 has taken 0.03986048698425293 seconds
# ID 467 has taken 0.09209156036376953 seconds
# ID 468 has taken 0.0511012077331543 seconds
# ID 469 has taken 0.10137414932250977 seconds
# ID 470 has taken 0.2684924602508545 seconds
# ID 471 has taken 0.14661741256713867 seconds
# ID 472 has taken 0.002003192901611328 seconds
# ID 473 has taken 0.2298142910003662 seconds
# ID 474 has taken 0.008518218994140625 seconds
# ID 475 has taken 0.006532192230224609 seconds
# ID 476 has taken 0.21394586563110352 seconds
# ID 477 has taken 0.0877523422241211 seconds
# ID 478 has taken 0.06956791877746582 seconds
# ID 479 has taken 0.15544724464416504 seconds
# ID 480 has taken 0.06705784797668457 seconds
# ID 481 has taken 0.19141101837158203 seconds
# ID 482 has taken 0.29552793502807617 seconds
# ID 483 has taken 0.05069112777709961 seconds
# ID 484 has taken 0.18171381950378418 seconds
# ID 485 has taken 0.013036489486694336 seconds
# ID 486 has taken 0.13213229179382324 seconds
# ID 487 has taken 0.14992976188659668 seconds
# ID 488 has taken 0.1034097671508789 seconds
# ID 489 has taken 0.20464468002319336 seconds
# ID 490 has taken 0.17643475532531738 seconds
# ID 491 has taken 0.016380786895751953 seconds
# ID 492 has taken 0.17572784423828125 seconds
# ID 493 has taken 0.1327824592590332 seconds
# ID 494 has taken 0.15604925155639648 seconds
# ID 495 has taken 0.06234097480773926 seconds
# ID 496 has taken 3.040513515472412 seconds
# ID 497 has taken 0.06138491630554199 seconds
# ID 498 has taken 0.021608352661132812 seconds
# ID 499 has taken 0.08824372291564941 seconds
# ID 500 has taken 0.19948673248291016 seconds
# ID 501 has taken 0.00408172607421875 seconds
# ID 502 has taken 0.0050547122955322266 seconds
# ID 503 has taken 0.0017366409301757812 seconds
# ID 504 has taken 0.001073598861694336 seconds
# ID 505 has taken 0.0 seconds
# ID 506 has taken 0.008835554122924805 seconds
# ID 507 has taken 0.0 seconds
# ID 508 has taken 0.0 seconds
# ID 509 has taken 0.0 seconds
# ID 510 has taken 0.10930728912353516 seconds
# ID 511 has taken 0.08217668533325195 seconds
# ID 512 has taken 0.04229903221130371 seconds
# ID 513 has taken 0.006700992584228516 seconds
# ID 514 has taken 0.033420562744140625 seconds
# ID 515 has taken 0.025719642639160156 seconds
# ID 516 has taken 0.030582427978515625 seconds
# ID 517 has taken 0.03072953224182129 seconds
# ID 518 has taken 0.04615664482116699 seconds
# ID 519 has taken 0.04249405860900879 seconds
# ID 520 has taken 0.08581995964050293 seconds
# ID 521 has taken 0.07700347900390625 seconds
# ID 522 has taken 0.044532060623168945 seconds
# ID 523 has taken 0.05619311332702637 seconds
# ID 524 has taken 0.05301237106323242 seconds
# ID 525 has taken 0.033586740493774414 seconds
# ID 526 has taken 0.04124951362609863 seconds
# ID 527 has taken 0.03324151039123535 seconds
# ID 528 has taken 0.04148244857788086 seconds
# ID 529 has taken 0.03221273422241211 seconds
# ID 530 has taken 0.027458667755126953 seconds
# ID 531 has taken 0.03821706771850586 seconds
# ID 532 has taken 0.03331494331359863 seconds
# ID 533 has taken 0.044287681579589844 seconds
# ID 534 has taken 0.07149672508239746 seconds
# ID 535 has taken 0.04352092742919922 seconds
# ID 536 has taken 0.05019974708557129 seconds
# ID 537 has taken 0.04125094413757324 seconds
# ID 538 has taken 0.04035782814025879 seconds
# ID 539 has taken 0.05045032501220703 seconds
# ID 540 has taken 0.03990578651428223 seconds
# ID 541 has taken 0.03242635726928711 seconds
# ID 542 has taken 0.034459829330444336 seconds
# ID 543 has taken 0.04301595687866211 seconds
# ID 544 has taken 0.037248849868774414 seconds
# ID 545 has taken 0.031297922134399414 seconds
# ID 546 has taken 0.040708065032958984 seconds
# ID 547 has taken 0.041303396224975586 seconds
# ID 548 has taken 0.02374100685119629 seconds
# ID 549 has taken 0.030812740325927734 seconds
# ID 550 has taken 0.014586925506591797 seconds
# ID 551 has taken 0.015011072158813477 seconds
# ID 552 has taken 0.03126788139343262 seconds
# ID 553 has taken 0.03323554992675781 seconds
# ID 554 has taken 0.022675037384033203 seconds
# ID 555 has taken 0.0312502384185791 seconds
# ID 556 has taken 0.03165912628173828 seconds
# ID 557 has taken 0.03406691551208496 seconds
# ID 558 has taken 0.038110971450805664 seconds
# ID 559 has taken 0.025010108947753906 seconds
# ID 560 has taken 0.03727865219116211 seconds
# ID 561 has taken 0.029335498809814453 seconds
# ID 562 has taken 0.049132585525512695 seconds
# ID 563 has taken 0.057373762130737305 seconds
# ID 564 has taken 0.050000667572021484 seconds
# ID 565 has taken 0.037586212158203125 seconds
# ID 566 has taken 0.0384211540222168 seconds
# ID 567 has taken 0.0429232120513916 seconds
# ID 568 has taken 0.03913259506225586 seconds
# ID 569 has taken 0.03810834884643555 seconds
# ID 570 has taken 0.04062056541442871 seconds
# ID 571 has taken 0.03741312026977539 seconds
# ID 572 has taken 0.03207063674926758 seconds
# ID 573 has taken 0.04042458534240723 seconds
# ID 574 has taken 0.035058021545410156 seconds
# ID 575 has taken 0.041436195373535156 seconds
# ID 576 has taken 0.032651424407958984 seconds
# ID 577 has taken 0.03902077674865723 seconds
# ID 578 has taken 0.03159761428833008 seconds
# ID 579 has taken 0.028991222381591797 seconds
# ID 580 has taken 0.03154349327087402 seconds
# ID 581 has taken 0.03402066230773926 seconds
# ID 582 has taken 0.041684865951538086 seconds
# ID 583 has taken 0.0408177375793457 seconds
# ID 584 has taken 0.037819862365722656 seconds
# ID 585 has taken 0.03611946105957031 seconds
# ID 586 has taken 0.03602027893066406 seconds
# ID 587 has taken 0.03332638740539551 seconds
# ID 588 has taken 0.023476839065551758 seconds
# ID 589 has taken 0.041525840759277344 seconds
# ID 590 has taken 0.03639340400695801 seconds
# ID 591 has taken 0.030288219451904297 seconds
# ID 592 has taken 0.026726961135864258 seconds
# ID 593 has taken 0.028591394424438477 seconds
# ID 594 has taken 0.029132604598999023 seconds
# ID 595 has taken 0.023904800415039062 seconds
# ID 596 has taken 0.03509259223937988 seconds
# ID 597 has taken 0.010511159896850586 seconds
# ID 598 has taken 0.06108880043029785 seconds
# ID 599 has taken 0.03164553642272949 seconds
# ID 600 has taken 0.03591465950012207 seconds
# ID 601 has taken 0.038957834243774414 seconds
# ID 602 has taken 0.03139066696166992 seconds
# ID 603 has taken 0.028278350830078125 seconds
# ID 604 has taken 0.027380943298339844 seconds
# ID 605 has taken 0.01588129997253418 seconds
# ID 606 has taken 0.031494140625 seconds
# ID 607 has taken 0.03159070014953613 seconds
# ID 608 has taken 0.025400161743164062 seconds
# ID 609 has taken 0.03126192092895508 seconds
# ID 610 has taken 0.03206992149353027 seconds
# ID 611 has taken 0.025243282318115234 seconds
# ID 612 has taken 0.0263214111328125 seconds
# ID 613 has taken 0.021174907684326172 seconds
# ID 614 has taken 0.04807114601135254 seconds
# ID 615 has taken 0.025940418243408203 seconds
# ID 616 has taken 0.024953603744506836 seconds
# ID 617 has taken 0.02473902702331543 seconds
# ID 618 has taken 0.016705751419067383 seconds
# ID 619 has taken 0.03685951232910156 seconds
# ID 620 has taken 0.04031109809875488 seconds
# ID 621 has taken 0.02454090118408203 seconds
# ID 622 has taken 0.05112099647521973 seconds
# ID 623 has taken 0.03932619094848633 seconds
# ID 624 has taken 0.026729583740234375 seconds
# ID 625 has taken 0.03435659408569336 seconds
# ID 626 has taken 0.031942129135131836 seconds
# ID 627 has taken 0.015769243240356445 seconds
# ID 628 has taken 0.03928780555725098 seconds
# ID 629 has taken 0.020470619201660156 seconds
# ID 630 has taken 0.039422035217285156 seconds
# ID 631 has taken 0.016248226165771484 seconds
# ID 632 has taken 0.04378485679626465 seconds
# ID 633 has taken 0.029047012329101562 seconds
# ID 634 has taken 0.019009828567504883 seconds
# ID 635 has taken 0.031760454177856445 seconds
# ID 636 has taken 0.022788524627685547 seconds
# ID 637 has taken 0.02456045150756836 seconds
# ID 638 has taken 0.028553247451782227 seconds
# ID 639 has taken 0.018958330154418945 seconds
# ID 640 has taken 0.02246689796447754 seconds
# ID 641 has taken 0.034737348556518555 seconds
# ID 642 has taken 0.021597623825073242 seconds
# ID 643 has taken 0.02647113800048828 seconds
# ID 644 has taken 0.027733802795410156 seconds
# ID 645 has taken 0.02631378173828125 seconds
# ID 646 has taken 0.013401031494140625 seconds
# ID 647 has taken 0.03977179527282715 seconds
# ID 648 has taken 0.030152320861816406 seconds
# ID 649 has taken 0.022835969924926758 seconds
# ID 650 has taken 0.030220746994018555 seconds
# ID 651 has taken 0.03032517433166504 seconds
# ID 652 has taken 0.03725290298461914 seconds
# ID 653 has taken 0.03180193901062012 seconds
# ID 654 has taken 0.025288820266723633 seconds
# ID 655 has taken 0.036188602447509766 seconds
# ID 656 has taken 0.03611445426940918 seconds
# ID 657 has taken 0.0338129997253418 seconds
# ID 658 has taken 0.03034830093383789 seconds
# ID 659 has taken 0.03175663948059082 seconds
# ID 660 has taken 0.029174327850341797 seconds
# ID 661 has taken 0.03029942512512207 seconds
# ID 662 has taken 0.02712535858154297 seconds
# ID 663 has taken 0.027652263641357422 seconds
# ID 664 has taken 0.025681257247924805 seconds
# ID 665 has taken 0.024380207061767578 seconds
# ID 666 has taken 0.031612396240234375 seconds
# ID 667 has taken 0.06116676330566406 seconds
# ID 668 has taken 0.018425703048706055 seconds
# ID 669 has taken 0.047176361083984375 seconds
# ID 670 has taken 0.04041600227355957 seconds
# ID 671 has taken 0.027149200439453125 seconds
# ID 672 has taken 0.0485689640045166 seconds
# ID 673 has taken 0.02889227867126465 seconds
# ID 674 has taken 0.04053020477294922 seconds
# ID 675 has taken 0.021985769271850586 seconds
# ID 676 has taken 0.022548675537109375 seconds
# ID 677 has taken 0.02750086784362793 seconds
# ID 678 has taken 0.026124954223632812 seconds
# ID 679 has taken 0.02149677276611328 seconds
# ID 680 has taken 0.03573799133300781 seconds
# ID 681 has taken 0.010583877563476562 seconds
# ID 682 has taken 0.03805351257324219 seconds
# ID 683 has taken 0.024651050567626953 seconds
# ID 684 has taken 0.026919126510620117 seconds
# ID 685 has taken 0.012963533401489258 seconds
# ID 686 has taken 0.02384495735168457 seconds
# ID 687 has taken 0.020978689193725586 seconds
# ID 688 has taken 0.025742769241333008 seconds
# ID 689 has taken 0.04552721977233887 seconds
# ID 690 has taken 0.04174232482910156 seconds
# ID 691 has taken 0.0 seconds
# ID 692 has taken 0.0035200119018554688 seconds
# ID 693 has taken 0.002096891403198242 seconds
# ID 694 has taken 0.0020020008087158203 seconds
# ID 695 has taken 0.001993417739868164 seconds
# ID 696 has taken 0.0019164085388183594 seconds
# ID 697 has taken 0.0 seconds
# ID 698 has taken 0.0 seconds
# ID 699 has taken 0.24250507354736328 seconds
# ID 700 has taken 0.3552696704864502 seconds
# ID 701 has taken 0.36603283882141113 seconds
# ID 702 has taken 0.6030809879302979 seconds
# ID 703 has taken 0.0 seconds
# ID 704 has taken 0.04472756385803223 seconds
# ID 705 has taken 0.0007314682006835938 seconds
# ID 706 has taken 0.09902143478393555 seconds
# ID 707 has taken 0.18793749809265137 seconds
# ID 708 has taken 0.032477378845214844 seconds
# ID 709 has taken 0.2464613914489746 seconds
# ID 710 has taken 0.26924896240234375 seconds
# ID 711 has taken 0.0 seconds
# ID 712 has taken 0.036684274673461914 seconds
# ID 713 has taken 0.10000848770141602 seconds
# ID 714 has taken 0.0 seconds
# ID 715 has taken 0.01486515998840332 seconds
# ID 716 has taken 0.018163681030273438 seconds
# ID 717 has taken 0.2306501865386963 seconds
# ID 718 has taken 0.5336418151855469 seconds
# ID 719 has taken 0.052451133728027344 seconds
# ID 720 has taken 0.1130990982055664 seconds
# ID 721 has taken 0.21860051155090332 seconds
# ID 722 has taken 0.1578671932220459 seconds
# ID 723 has taken 0.27265167236328125 seconds
# ID 724 has taken 1.4180588722229004 seconds
# ID 725 has taken 0.7224993705749512 seconds
# ID 726 has taken 1.026719331741333 seconds
# ID 727 has taken 0.7083051204681396 seconds
# ID 728 has taken 0.007766008377075195 seconds
# ID 729 has taken 0.05841064453125 seconds
# ID 730 has taken 0.002061128616333008 seconds
# ID 731 has taken 0.16835451126098633 seconds
# ID 732 has taken 0.1357743740081787 seconds
# ID 733 has taken 0.19800090789794922 seconds
# ID 734 has taken 0.2954587936401367 seconds
# ID 735 has taken 0.05807065963745117 seconds
# ID 736 has taken 0.3388068675994873 seconds
# ID 737 has taken 0.2430896759033203 seconds
# ID 738 has taken 1.0505528450012207 seconds
# ID 739 has taken 1.3422112464904785 seconds
# ID 740 has taken 1.3818659782409668 seconds
# ID 741 has taken 0.901648759841919 seconds
# ID 742 has taken 1.2145168781280518 seconds
# ID 743 has taken 0.019205808639526367 seconds
# ID 744 has taken 0.11443376541137695 seconds
# ID 745 has taken 0.0832362174987793 seconds
# ID 746 has taken 0.031308889389038086 seconds
# ID 747 has taken 0.021575927734375 seconds
# ID 748 has taken 0.20658302307128906 seconds
# ID 749 has taken 0.03226423263549805 seconds
# ID 750 has taken 0.0647742748260498 seconds
# ID 751 has taken 0.14581561088562012 seconds
# ID 752 has taken 0.07238221168518066 seconds
# ID 753 has taken 0.11551499366760254 seconds
# ID 754 has taken 0.1266641616821289 seconds
# ID 755 has taken 0.11426806449890137 seconds
# ID 756 has taken 0.04152536392211914 seconds
# ID 757 has taken 0.02131366729736328 seconds
# ID 758 has taken 0.452526330947876 seconds
# ID 759 has taken 0.34227776527404785 seconds
# ID 760 has taken 0.42786288261413574 seconds
# ID 761 has taken 0.4410836696624756 seconds
# ID 762 has taken 0.06868195533752441 seconds
# ID 763 has taken 0.3867928981781006 seconds
# ID 764 has taken 0.3228015899658203 seconds
# ID 765 has taken 0.370391845703125 seconds
# ID 766 has taken 0.044564247131347656 seconds
# ID 767 has taken 0.3663358688354492 seconds
# ID 768 has taken 0.023631811141967773 seconds
# ID 769 has taken 0.1085348129272461 seconds
# ID 770 has taken 0.0006825923919677734 seconds
# ID 771 has taken 0.8048481941223145 seconds
# ID 772 has taken 0.4551074504852295 seconds
# ID 773 has taken 0.7641122341156006 seconds
# ID 774 has taken 0.642258882522583 seconds
# ID 775 has taken 0.29206085205078125 seconds
# ID 776 has taken 0.15703916549682617 seconds
# ID 777 has taken 0.5338759422302246 seconds
# ID 778 has taken 0.07100224494934082 seconds
# ID 779 has taken 0.287278413772583 seconds
# ID 780 has taken 0.09962821006774902 seconds
# ID 781 has taken 0.0420076847076416 seconds
# ID 782 has taken 0.31701087951660156 seconds
# ID 783 has taken 0.0 seconds
# ID 784 has taken 0.37494587898254395 seconds
# ID 785 has taken 0.27437520027160645 seconds
# ID 786 has taken 0.007640838623046875 seconds
# ID 787 has taken 0.07298088073730469 seconds
# ID 788 has taken 0.0033490657806396484 seconds
# ID 789 has taken 0.14070892333984375 seconds
# ID 790 has taken 0.18106603622436523 seconds
# ID 791 has taken 0.18482732772827148 seconds
# ID 792 has taken 0.15424776077270508 seconds
# ID 793 has taken 0.01999187469482422 seconds
# ID 794 has taken 0.026584863662719727 seconds
# ID 795 has taken 0.06755852699279785 seconds
# ID 796 has taken 0.03305411338806152 seconds
# ID 797 has taken 0.06558775901794434 seconds
# ID 798 has taken 0.04377174377441406 seconds
# ID 799 has taken 0.07256555557250977 seconds
# ID 800 has taken 0.07333016395568848 seconds
# ID 801 has taken 0.2790977954864502 seconds
# ID 802 has taken 0.23983383178710938 seconds
# ID 803 has taken 0.1585979461669922 seconds
# ID 804 has taken 0.12455987930297852 seconds
# ID 805 has taken 0.18445730209350586 seconds
# ID 806 has taken 0.042118072509765625 seconds
# ID 807 has taken 0.31525349617004395 seconds
# ID 808 has taken 0.3715229034423828 seconds
# ID 809 has taken 0.36064934730529785 seconds
# ID 810 has taken 0.39260172843933105 seconds
# ID 811 has taken 0.4240260124206543 seconds
# ID 812 has taken 0.32820844650268555 seconds
# ID 813 has taken 0.5748414993286133 seconds
# ID 814 has taken 0.3932304382324219 seconds
# ID 815 has taken 0.504711389541626 seconds
# ID 816 has taken 0.41742920875549316 seconds
# ID 817 has taken 0.4716043472290039 seconds
# ID 818 has taken 0.3919808864593506 seconds
# ID 819 has taken 0.5832185745239258 seconds
# ID 820 has taken 0.43483400344848633 seconds
# ID 821 has taken 0.006850004196166992 seconds
# ID 822 has taken 0.31008458137512207 seconds
# ID 823 has taken 0.16534757614135742 seconds
# ID 824 has taken 0.052306175231933594 seconds
# ID 825 has taken 0.10926365852355957 seconds
# ID 826 has taken 0.4281899929046631 seconds
# ID 827 has taken 0.6159625053405762 seconds
# ID 828 has taken 0.15457701683044434 seconds
# ID 829 has taken 0.15737533569335938 seconds
# ID 830 has taken 0.13025546073913574 seconds
# ID 831 has taken 0.06548476219177246 seconds
# ID 832 has taken 0.05972146987915039 seconds
# ID 833 has taken 0.0733335018157959 seconds
# ID 834 has taken 0.06667351722717285 seconds
# ID 835 has taken 0.06758928298950195 seconds
# ID 836 has taken 0.05059814453125 seconds
# ID 837 has taken 0.08765459060668945 seconds
# ID 838 has taken 0.08680295944213867 seconds
# ID 839 has taken 0.08015990257263184 seconds
# ID 840 has taken 0.08611750602722168 seconds
# ID 841 has taken 0.47045421600341797 seconds
# ID 842 has taken 0.01771998405456543 seconds
# ID 843 has taken 0.3360621929168701 seconds
# ID 844 has taken 0.24071717262268066 seconds
# ID 845 has taken 0.3084266185760498 seconds
# ID 846 has taken 0.15134310722351074 seconds
# ID 847 has taken 0.14401531219482422 seconds
# ID 848 has taken 0.10348176956176758 seconds
# ID 849 has taken 0.13383722305297852 seconds
# ID 850 has taken 0.0999302864074707 seconds
# ID 851 has taken 0.09531736373901367 seconds
# ID 852 has taken 0.02729177474975586 seconds
# ID 853 has taken 0.022673845291137695 seconds
# ID 854 has taken 0.13450884819030762 seconds
# ID 855 has taken 0.24067378044128418 seconds
# ID 856 has taken 0.11468505859375 seconds
# ID 857 has taken 0.18377447128295898 seconds
# ID 858 has taken 0.08020401000976562 seconds
# ID 859 has taken 0.027707815170288086 seconds
# ID 860 has taken 0.3731999397277832 seconds
# ID 861 has taken 0.11606407165527344 seconds
# ID 862 has taken 0.2573573589324951 seconds
# ID 863 has taken 0.0030546188354492188 seconds
# ID 864 has taken 0.3114778995513916 seconds
# ID 865 has taken 0.3001515865325928 seconds
# ID 866 has taken 0.44367194175720215 seconds
# ID 867 has taken 0.015348434448242188 seconds
# ID 868 has taken 0.10274934768676758 seconds
# ID 869 has taken 0.06618070602416992 seconds
# ID 870 has taken 0.17200231552124023 seconds
# ID 871 has taken 0.0 seconds
# ID 872 has taken 0.017134666442871094 seconds
# ID 873 has taken 0.09347248077392578 seconds
# ID 874 has taken 0.09305214881896973 seconds
# ID 875 has taken 0.07271504402160645 seconds
# ID 876 has taken 0.2813143730163574 seconds
# ID 877 has taken 0.0682072639465332 seconds
# ID 878 has taken 0.04889512062072754 seconds
# ID 879 has taken 1.4412529468536377 seconds
# ID 880 has taken 1.7062337398529053 seconds
# ID 881 has taken 1.8190057277679443 seconds
# ID 882 has taken 2.003333568572998 seconds
# ID 883 has taken 1.5260074138641357 seconds
# ID 884 has taken 2.1993210315704346 seconds
# ID 885 has taken 0.01573467254638672 seconds
# ID 886 has taken 0.17238998413085938 seconds
# ID 887 has taken 0.02415323257446289 seconds
# ID 888 has taken 0.2620053291320801 seconds
# ID 889 has taken 0.0317075252532959 seconds
# ID 890 has taken 0.08463478088378906 seconds
# ID 891 has taken 0.07201957702636719 seconds
# ID 892 has taken 0.061208248138427734 seconds
# ID 893 has taken 0.2472851276397705 seconds
# ID 894 has taken 0.46410202980041504 seconds
# ID 895 has taken 0.3109011650085449 seconds
# ID 896 has taken 0.22557783126831055 seconds
# ID 897 has taken 0.2835268974304199 seconds
# ID 898 has taken 0.3512890338897705 seconds
# ID 899 has taken 0.2845487594604492 seconds
# ID 900 has taken 0.28346776962280273 seconds
# ID 901 has taken 0.3323557376861572 seconds
# ID 902 has taken 0.8529751300811768 seconds
# ID 903 has taken 0.7281041145324707 seconds
# ID 904 has taken 0.731835126876831 seconds
# ID 905 has taken 0.8240630626678467 seconds
# ID 906 has taken 0.8972651958465576 seconds
# ID 907 has taken 0.8229274749755859 seconds
# ID 908 has taken 0.921372652053833 seconds
# ID 909 has taken 0.5290260314941406 seconds
# ID 910 has taken 0.015619516372680664 seconds
# ID 911 has taken 0.06357836723327637 seconds
# ID 912 has taken 0.7175178527832031 seconds
# ID 913 has taken 0.8710172176361084 seconds
# ID 914 has taken 0.6204357147216797 seconds
# ID 915 has taken 0.3223137855529785 seconds
# ID 916 has taken 0.7309913635253906 seconds
# ID 917 has taken 0.015848636627197266 seconds
# ID 918 has taken 1.6367056369781494 seconds
# ID 919 has taken 1.5207209587097168 seconds
# ID 920 has taken 0.1440114974975586 seconds
# ID 921 has taken 0.1525881290435791 seconds
# ID 922 has taken 0.06849241256713867 seconds
# ID 923 has taken 0.2258753776550293 seconds
# ID 924 has taken 0.05738544464111328 seconds
# ID 925 has taken 0.16309118270874023 seconds
# ID 926 has taken 0.5336513519287109 seconds
# ID 927 has taken 0.008347034454345703 seconds
# ID 928 has taken 0.3475518226623535 seconds
# ID 929 has taken 0.12333059310913086 seconds
# ID 930 has taken 0.032128334045410156 seconds
# ID 931 has taken 0.14082098007202148 seconds
# ID 932 has taken 0.17116951942443848 seconds
# ID 933 has taken 1.7360095977783203 seconds
# ID 934 has taken 0.05321002006530762 seconds
# ID 935 has taken 1.1395559310913086 seconds
# ID 936 has taken 0.43803834915161133 seconds
# ID 937 has taken 0.4225623607635498 seconds
# ID 938 has taken 0.1417403221130371 seconds
# ID 939 has taken 0.06476855278015137 seconds
# ID 940 has taken 0.11719155311584473 seconds
# ID 941 has taken 0.008545637130737305 seconds
# ID 942 has taken 0.05174422264099121 seconds
# ID 943 has taken 0.24434280395507812 seconds
# ID 944 has taken 0.1899583339691162 seconds
# ID 945 has taken 0.2122206687927246 seconds
# ID 946 has taken 0.1184854507446289 seconds
# ID 947 has taken 0.14042305946350098 seconds
# ID 948 has taken 0.10274553298950195 seconds
# ID 949 has taken 0.06735968589782715 seconds
# ID 950 has taken 0.42541050910949707 seconds
# ID 951 has taken 0.043683767318725586 seconds
# ID 952 has taken 0.06082463264465332 seconds
# ID 953 has taken 1.0938310623168945 seconds
# ID 954 has taken 0.4987304210662842 seconds
# ID 955 has taken 0.5057408809661865 seconds
# ID 956 has taken 0.5834379196166992 seconds
# ID 957 has taken 1.2091748714447021 seconds
# ID 958 has taken 0.034383535385131836 seconds
# ID 959 has taken 0.8477530479431152 seconds
# ID 960 has taken 0.666541337966919 seconds
# ID 961 has taken 0.05843472480773926 seconds
# ID 962 has taken 0.05951523780822754 seconds
# ID 963 has taken 0.3485291004180908 seconds
# ID 964 has taken 0.28548765182495117 seconds
# ID 965 has taken 0.03902173042297363 seconds
# ID 966 has taken 0.5095396041870117 seconds
# ID 967 has taken 0.1876842975616455 seconds
# ID 968 has taken 0.307401180267334 seconds
# ID 969 has taken 0.05901479721069336 seconds
# ID 970 has taken 0.4336130619049072 seconds
# ID 971 has taken 0.20766258239746094 seconds
# ID 972 has taken 0.06650829315185547 seconds
# ID 973 has taken 0.0708627700805664 seconds
# ID 974 has taken 0.2953469753265381 seconds
# ID 975 has taken 0.028681516647338867 seconds
# ID 976 has taken 1.2668843269348145 seconds
# ID 977 has taken 0.1593492031097412 seconds
# ID 978 has taken 0.021663188934326172 seconds
# ID 979 has taken 0.09359288215637207 seconds
# ID 980 has taken 0.04489874839782715 seconds
# ID 981 has taken 0.4264101982116699 seconds
# ID 982 has taken 0.28743505477905273 seconds
# ID 983 has taken 0.42914891242980957 seconds
# ID 984 has taken 0.14188289642333984 seconds
# ID 985 has taken 0.09170651435852051 seconds
# ID 986 has taken 0.034394264221191406 seconds
# ID 987 has taken 0.030308008193969727 seconds
# ID 988 has taken 0.016332387924194336 seconds
# ID 989 has taken 0.0029993057250976562 seconds
# ID 990 has taken 0.0051116943359375 seconds
# ID 991 has taken 0.00600123405456543 seconds
# ID 992 has taken 0.07560515403747559 seconds
# ID 993 has taken 0.3223872184753418 seconds
# ID 994 has taken 0.2728276252746582 seconds
# ID 995 has taken 0.8504743576049805 seconds
# ID 996 has taken 1.0147154331207275 seconds
# ID 997 has taken 1.1386542320251465 seconds
# ID 998 has taken 1.828094720840454 seconds
# ID 999 has taken 0.8382079601287842 seconds
# ID 1000 has taken 0.6116137504577637 seconds
# ID 1001 has taken 0.41373133659362793 seconds
# ID 1002 has taken 0.6667623519897461 seconds
# ID 1003 has taken 0.4836280345916748 seconds
# ID 1004 has taken 0.08481073379516602 seconds
# ID 1005 has taken 0.5737509727478027 seconds
# ID 1006 has taken 0.5777685642242432 seconds
# ID 1007 has taken 0.04010295867919922 seconds
# ID 1008 has taken 0.158097505569458 seconds
# ID 1009 has taken 0.3879268169403076 seconds
# ID 1010 has taken 0.054207801818847656 seconds
# ID 1011 has taken 0.003988742828369141 seconds
# ID 1012 has taken 0.05975914001464844 seconds
# ID 1013 has taken 0.0599980354309082 seconds
# ID 1014 has taken 0.042636871337890625 seconds
# ID 1015 has taken 0.09682941436767578 seconds
# ID 1016 has taken 0.22705531120300293 seconds
# ID 1017 has taken 0.12369418144226074 seconds
# ID 1018 has taken 0.26523566246032715 seconds
# ID 1019 has taken 0.6131107807159424 seconds
# ID 1020 has taken 0.10597038269042969 seconds
# ID 1021 has taken 0.03175091743469238 seconds
# ID 1022 has taken 1.5744218826293945 seconds
# ID 1023 has taken 0.7129158973693848 seconds
# ID 1024 has taken 0.01603865623474121 seconds
# ID 1025 has taken 0.15759730339050293 seconds
# ID 1026 has taken 0.1422433853149414 seconds
# ID 1027 has taken 0.3465447425842285 seconds
# ID 1028 has taken 0.019513607025146484 seconds
# ID 1029 has taken 0.1345834732055664 seconds
# ID 1030 has taken 0.3968982696533203 seconds
# ID 1031 has taken 0.06560516357421875 seconds
# ID 1032 has taken 0.18559622764587402 seconds
# ID 1033 has taken 0.6804282665252686 seconds
# ID 1034 has taken 0.10148048400878906 seconds
# ID 1035 has taken 0.790369987487793 seconds
# ID 1036 has taken 0.10763072967529297 seconds
# ID 1037 has taken 0.034494876861572266 seconds
# ID 1038 has taken 0.1686084270477295 seconds
# ID 1039 has taken 0.0 seconds
# ID 1040 has taken 0.07098531723022461 seconds
# ID 1041 has taken 0.06604504585266113 seconds
# ID 1042 has taken 0.1406700611114502 seconds
# ID 1043 has taken 0.24100255966186523 seconds
# ID 1044 has taken 0.17748761177062988 seconds
# ID 1045 has taken 0.26872920989990234 seconds
# ID 1046 has taken 0.11916708946228027 seconds
# ID 1047 has taken 0.203294038772583 seconds
# ID 1048 has taken 0.27500057220458984 seconds
# ID 1049 has taken 0.23552727699279785 seconds
# ID 1050 has taken 0.06474018096923828 seconds
# ID 1051 has taken 0.027611970901489258 seconds
# ID 1052 has taken 0.007015228271484375 seconds
# ID 1053 has taken 0.009005308151245117 seconds
# ID 1054 has taken 0.23680567741394043 seconds
# ID 1055 has taken 0.008460521697998047 seconds
# ID 1056 has taken 0.349806547164917 seconds
# ID 1057 has taken 0.24209952354431152 seconds
# ID 1058 has taken 0.3350062370300293 seconds
# ID 1059 has taken 0.03123164176940918 seconds
# ID 1060 has taken 0.006646156311035156 seconds
# ID 1061 has taken 0.2540719509124756 seconds
# ID 1062 has taken 0.25444650650024414 seconds
# ID 1063 has taken 0.3969991207122803 seconds
# ID 1064 has taken 0.17049717903137207 seconds
# ID 1065 has taken 0.1688554286956787 seconds
# ID 1066 has taken 0.05546116828918457 seconds
# ID 1067 has taken 0.21808362007141113 seconds
# ID 1068 has taken 0.7072994709014893 seconds
# ID 1069 has taken 0.005294084548950195 seconds
# ID 1070 has taken 0.6401596069335938 seconds
# ID 1071 has taken 0.2578315734863281 seconds
# ID 1072 has taken 0.05571103096008301 seconds
# ID 1073 has taken 0.14953327178955078 seconds
# ID 1074 has taken 0.2554645538330078 seconds
# ID 1075 has taken 0.2491157054901123 seconds
# ID 1076 has taken 0.5119976997375488 seconds
# ID 1077 has taken 0.11180353164672852 seconds
# ID 1078 has taken 0.1398015022277832 seconds
# ID 1079 has taken 0.13372325897216797 seconds
# ID 1080 has taken 1.2120437622070312 seconds
# ID 1081 has taken 1.0915613174438477 seconds
# ID 1082 has taken 1.6928856372833252 seconds
# ID 1083 has taken 0.14165973663330078 seconds
# ID 1084 has taken 0.34566688537597656 seconds
# ID 1085 has taken 0.20430541038513184 seconds
# ID 1086 has taken 0.15688538551330566 seconds
# ...
# ID 4083 has taken 0.017132043838500977 seconds
# ID 4084 has taken 0.06610226631164551 seconds
# ID 4085 has taken 0.011023521423339844 seconds
# ID 4086 has taken 0.5097846984863281 seconds
# ID 4087 has taken 0.02490520477294922 seconds
# ID 4088 has taken 0.017705440521240234 seconds
# ID 4089 has taken 0.04700422286987305 seconds
# ID 4090 has taken 0.10598444938659668 seconds
# ID 4091 has taken 1.0792419910430908 seconds
# ID 4092 has taken 1.1138944625854492 seconds
# ID 4093 has taken 1.1264684200286865 seconds
# ID 4094 has taken 1.0013878345489502 seconds
# ID 4095 has taken 0.14177441596984863 seconds
# ID 4096 has taken 0.2669718265533447 seconds
# ID 4097 has taken 0.2321157455444336 seconds
# ID 4098 has taken 0.16623878479003906 seconds
# ID 4099 has taken 0.14157676696777344 seconds
# ID 4100 has taken 0.14295530319213867 seconds
# ID 4101 has taken 0.11062264442443848 seconds
# ID 4102 has taken 0.14474225044250488 seconds
# ID 4103 has taken 0.11722779273986816 seconds
# ID 4104 has taken 0.07146596908569336 seconds
# ID 4105 has taken 0.12292337417602539 seconds
# ID 4106 has taken 0.133497953414917 seconds
# ID 4107 has taken 0.03173255920410156 seconds
# ID 4108 has taken 0.08527159690856934 seconds
# ID 4109 has taken 0.022876501083374023 seconds
# ID 4110 has taken 0.5056674480438232 seconds
# ID 4111 has taken 0.014565229415893555 seconds
# ID 4112 has taken 0.1145181655883789 seconds
# ID 4113 has taken 0.07916712760925293 seconds
# ID 4114 has taken 0.005271196365356445 seconds
# ID 4115 has taken 0.11253881454467773 seconds
# ID 4116 has taken 0.0076885223388671875 seconds
# ID 4117 has taken 0.0012013912200927734 seconds
# ID 4118 has taken 0.669929027557373 seconds
# ID 4119 has taken 0.346066951751709 seconds
# ID 4120 has taken 0.532599925994873 seconds
# ID 4121 has taken 0.7639155387878418 seconds
# ID 4122 has taken 0.3142673969268799 seconds
# ID 4123 has taken 0.12334990501403809 seconds
# ID 4124 has taken 0.1850428581237793 seconds
# ID 4125 has taken 0.34168171882629395 seconds
# ID 4126 has taken 0.1483907699584961 seconds
# ID 4127 has taken 0.4086015224456787 seconds
# ID 4128 has taken 0.379138708114624 seconds
# ID 4129 has taken 0.012969493865966797 seconds
# ID 4130 has taken 0.0624537467956543 seconds
# ID 4131 has taken 0.36841487884521484 seconds
# ID 4132 has taken 0.05232834815979004 seconds
# ID 4133 has taken 0.258059024810791 seconds
# ID 4134 has taken 0.17599225044250488 seconds
# ID 4135 has taken 0.21589255332946777 seconds
# ID 4136 has taken 0.12578749656677246 seconds
# ID 4137 has taken 0.09965729713439941 seconds
# ID 4138 has taken 0.394611120223999 seconds
# ID 4139 has taken 0.06868982315063477 seconds
# ID 4140 has taken 0.10585403442382812 seconds
# ID 4141 has taken 0.185560941696167 seconds
# ID 4142 has taken 0.2649357318878174 seconds
# ID 4143 has taken 0.06650137901306152 seconds
# ID 4144 has taken 0.041834115982055664 seconds
# ID 4145 has taken 0.049840450286865234 seconds
# ID 4146 has taken 0.03337693214416504 seconds
# ID 4147 has taken 0.0248260498046875 seconds
# ID 4148 has taken 0.020085573196411133 seconds
# ID 4149 has taken 0.07161903381347656 seconds
# ID 4150 has taken 0.07488322257995605 seconds
# ID 4151 has taken 0.0833902359008789 seconds
# ID 4152 has taken 0.6414661407470703 seconds
# ID 4153 has taken 0.6592433452606201 seconds
# ID 4154 has taken 0.03316688537597656 seconds
# ID 4155 has taken 0.0 seconds
# ID 4156 has taken 0.03336691856384277 seconds
# ID 4157 has taken 0.04198861122131348 seconds
# ID 4158 has taken 0.011744022369384766 seconds
# ID 4159 has taken 0.6332893371582031 seconds
# ID 4160 has taken 0.10335397720336914 seconds
# ID 4161 has taken 0.25344324111938477 seconds
# ID 4162 has taken 0.0572209358215332 seconds
# ID 4163 has taken 0.20297670364379883 seconds
# ID 4164 has taken 1.219127893447876 seconds
# ID 4165 has taken 1.9074790477752686 seconds
# ID 4166 has taken 0.1780564785003662 seconds
# ID 4167 has taken 0.0 seconds
# ID 4168 has taken 0.3275935649871826 seconds
# ID 4169 has taken 0.42314648628234863 seconds
# ID 4170 has taken 0.2520277500152588 seconds
# ID 4171 has taken 0.20530009269714355 seconds
# ID 4172 has taken 0.04690670967102051 seconds
# ID 4173 has taken 0.3146991729736328 seconds
# ID 4174 has taken 0.04737710952758789 seconds
# ID 4175 has taken 0.0 seconds
# ID 4176 has taken 0.37987732887268066 seconds
# ID 4177 has taken 0.07596969604492188 seconds
# ID 4178 has taken 0.5828282833099365 seconds
# ID 4179 has taken 0.5682542324066162 seconds
# ID 4180 has taken 0.12677836418151855 seconds
# ID 4181 has taken 0.33922290802001953 seconds
# ID 4182 has taken 0.1999971866607666 seconds
# ID 4183 has taken 0.1962895393371582 seconds
# ID 4184 has taken 0.32552552223205566 seconds
# ID 4185 has taken 0.12109041213989258 seconds
# ID 4186 has taken 0.10308670997619629 seconds
# ID 4187 has taken 0.35270261764526367 seconds
# ID 4188 has taken 0.16219091415405273 seconds
# ID 4189 has taken 0.020215988159179688 seconds
# ID 4190 has taken 0.21823620796203613 seconds
# ID 4191 has taken 0.11360478401184082 seconds
# ID 4192 has taken 0.33298349380493164 seconds
# ID 4193 has taken 0.37480902671813965 seconds
# ID 4194 has taken 0.31562256813049316 seconds
# ID 4195 has taken 0.39110589027404785 seconds
# ID 4196 has taken 0.025022506713867188 seconds
# ID 4197 has taken 0.1835484504699707 seconds
# ID 4198 has taken 0.04182600975036621 seconds
# ID 4199 has taken 0.41606640815734863 seconds
# ID 4200 has taken 0.30776309967041016 seconds
# ID 4201 has taken 0.050798892974853516 seconds
# ID 4202 has taken 0.11672735214233398 seconds
# ID 4203 has taken 0.10814809799194336 seconds
# ID 4204 has taken 0.14984917640686035 seconds
# ID 4205 has taken 0.26073312759399414 seconds
# ID 4206 has taken 0.20414233207702637 seconds
# ID 4207 has taken 0.166581392288208 seconds
# ID 4208 has taken 0.08725094795227051 seconds
# ID 4209 has taken 0.08803892135620117 seconds
# ID 4210 has taken 0.03834867477416992 seconds
# ID 4211 has taken 0.6854591369628906 seconds
# ID 4212 has taken 0.3654313087463379 seconds
# ID 4213 has taken 0.016823768615722656 seconds
# ID 4214 has taken 0.032379865646362305 seconds
# ID 4215 has taken 0.9428019523620605 seconds
# ID 4216 has taken 0.8061294555664062 seconds
# ID 4217 has taken 0.9538707733154297 seconds
# ID 4218 has taken 1.1211578845977783 seconds
# ID 4219 has taken 1.5723462104797363 seconds
# ID 4220 has taken 0.03125929832458496 seconds
# ID 4221 has taken 0.49149274826049805 seconds
# ID 4222 has taken 0.4075431823730469 seconds
# ID 4223 has taken 0.4344925880432129 seconds
# ID 4224 has taken 0.5430576801300049 seconds
# ID 4225 has taken 0.3929882049560547 seconds
# ID 4226 has taken 0.5996139049530029 seconds
# ID 4227 has taken 1.3216097354888916 seconds
# ID 4228 has taken 0.13552045822143555 seconds
# ID 4229 has taken 0.01706099510192871 seconds
# ID 4230 has taken 0.0354304313659668 seconds
# ID 4231 has taken 0.0348505973815918 seconds
# ID 4232 has taken 0.01726388931274414 seconds
# ID 4233 has taken 0.02521967887878418 seconds
# ID 4234 has taken 0.02765035629272461 seconds
# ID 4235 has taken 0.017406940460205078 seconds
# ID 4236 has taken 0.021961212158203125 seconds
# ID 4237 has taken 0.023849964141845703 seconds
# ID 4238 has taken 0.027677297592163086 seconds
# ID 4239 has taken 0.04730510711669922 seconds
# ID 4240 has taken 0.10021543502807617 seconds
# ID 4241 has taken 0.11335110664367676 seconds
# ID 4242 has taken 0.0063457489013671875 seconds
# ID 4243 has taken 0.011241912841796875 seconds
# ID 4244 has taken 0.11173224449157715 seconds
# ID 4245 has taken 0.08307266235351562 seconds
# ID 4246 has taken 0.013280630111694336 seconds
# ID 4247 has taken 0.2610764503479004 seconds
# ID 4248 has taken 0.04579424858093262 seconds
# ID 4249 has taken 0.6056962013244629 seconds
# ID 4250 has taken 0.12179231643676758 seconds
# ID 4251 has taken 1.5279006958007812 seconds
# ID 4252 has taken 0.09816241264343262 seconds
# ID 4253 has taken 1.4258029460906982 seconds
# ID 4254 has taken 0.04492330551147461 seconds
# ID 4255 has taken 0.041283369064331055 seconds
# ID 4256 has taken 1.0951263904571533 seconds
# ID 4257 has taken 0.0909881591796875 seconds
# ID 4258 has taken 0.36611342430114746 seconds
# ID 4259 has taken 0.34421205520629883 seconds
# ID 4260 has taken 0.33692145347595215 seconds
# ID 4261 has taken 0.65338134765625 seconds
# ID 4262 has taken 0.5372476577758789 seconds
# ID 4263 has taken 0.4820523262023926 seconds
# ID 4264 has taken 0.1571333408355713 seconds
# ID 4265 has taken 0.0750434398651123 seconds
# ID 4266 has taken 0.43604230880737305 seconds
# ID 4267 has taken 0.7251014709472656 seconds
# ID 4268 has taken 0.44983792304992676 seconds
# ID 4269 has taken 0.29942798614501953 seconds
# ID 4270 has taken 0.16873431205749512 seconds
# ID 4271 has taken 0.30234527587890625 seconds
# ID 4272 has taken 0.2889115810394287 seconds
# ID 4273 has taken 0.40613651275634766 seconds
# ID 4274 has taken 0.5590038299560547 seconds
# ID 4275 has taken 0.4470953941345215 seconds
# ID 4276 has taken 0.30554914474487305 seconds
# ID 4277 has taken 0.3640446662902832 seconds
# ID 4278 has taken 0.4903421401977539 seconds
# ID 4279 has taken 0.009523391723632812 seconds
# ID 4280 has taken 0.8866112232208252 seconds
# ID 4281 has taken 0.8216052055358887 seconds
# ID 4282 has taken 0.2848629951477051 seconds
# ID 4283 has taken 0.0 seconds
# ID 4284 has taken 0.0 seconds
# ID 4285 has taken 0.062337636947631836 seconds
# ID 4286 has taken 0.2524597644805908 seconds
# ID 4287 has taken 0.04689383506774902 seconds
# ID 4288 has taken 0.4401547908782959 seconds
# ID 4289 has taken 0.12669062614440918 seconds
# ID 4290 has taken 0.5885634422302246 seconds
# ID 4291 has taken 0.07073545455932617 seconds
# ID 4292 has taken 0.18556785583496094 seconds
# ID 4293 has taken 0.13440847396850586 seconds
# ID 4294 has taken 0.08592534065246582 seconds
# ID 4295 has taken 0.06326556205749512 seconds
# ID 4296 has taken 0.06342887878417969 seconds
# ID 4297 has taken 0.23435211181640625 seconds
# ID 4298 has taken 0.3623018264770508 seconds
# ID 4299 has taken 0.0 seconds
# ID 4300 has taken 0.07713675498962402 seconds
# ID 4301 has taken 0.04603385925292969 seconds
# ID 4302 has taken 0.5213747024536133 seconds
# ID 4303 has taken 0.17052960395812988 seconds
# ID 4304 has taken 0.3620109558105469 seconds
# ID 4305 has taken 5.520463228225708 seconds
# ID 4306 has taken 3.7029500007629395 seconds
# ID 4307 has taken 3.6807761192321777 seconds
# ID 4308 has taken 3.7712411880493164 seconds
# ID 4309 has taken 4.423967123031616 seconds
# ID 4310 has taken 0.2885599136352539 seconds
# ID 4311 has taken 0.7759544849395752 seconds
# ID 4312 has taken 0.3896751403808594 seconds
# ID 4313 has taken 0.3687474727630615 seconds
# ID 4314 has taken 0.011569023132324219 seconds
# ID 4315 has taken 0.04745125770568848 seconds
# ID 4316 has taken 0.031228303909301758 seconds
# ID 4317 has taken 0.2370893955230713 seconds
# ID 4318 has taken 0.06982421875 seconds
# ID 4319 has taken 0.03845548629760742 seconds
# ID 4320 has taken 0.03124856948852539 seconds
# ID 4321 has taken 0.04689192771911621 seconds
# ID 4322 has taken 0.04660487174987793 seconds
# ID 4323 has taken 0.05449700355529785 seconds
# ID 4324 has taken 0.11229562759399414 seconds
# ID 4325 has taken 0.0035240650177001953 seconds
# ID 4326 has taken 0.0 seconds
# ID 4327 has taken 0.1528780460357666 seconds
# ID 4328 has taken 0.01645207405090332 seconds
# ID 4329 has taken 0.08671736717224121 seconds
# ID 4330 has taken 0.030928850173950195 seconds
# ID 4331 has taken 0.11136841773986816 seconds
# ID 4332 has taken 0.08461666107177734 seconds
# ID 4333 has taken 0.1482696533203125 seconds
# ID 4334 has taken 0.010627031326293945 seconds
# ID 4335 has taken 0.17767620086669922 seconds
# ID 4336 has taken 0.11499810218811035 seconds
# ID 4337 has taken 0.2515232563018799 seconds
# ID 4338 has taken 0.07133626937866211 seconds
# ID 4339 has taken 0.2993338108062744 seconds
# ID 4340 has taken 0.18156170845031738 seconds
# ID 4341 has taken 0.3697547912597656 seconds
# ID 4342 has taken 0.04742240905761719 seconds
# ID 4343 has taken 0.011154651641845703 seconds
# ID 4344 has taken 0.05660438537597656 seconds
# ID 4345 has taken 0.016272783279418945 seconds
# ID 4346 has taken 0.01500844955444336 seconds
# ID 4347 has taken 0.34471893310546875 seconds
# ID 4348 has taken 0.03313589096069336 seconds
# ID 4349 has taken 0.0941770076751709 seconds
# ID 4350 has taken 0.015030622482299805 seconds
# ID 4351 has taken 0.047186851501464844 seconds
# ID 4352 has taken 0.1022038459777832 seconds
# ID 4353 has taken 0.08989429473876953 seconds
# ID 4354 has taken 0.03113102912902832 seconds
# ID 4355 has taken 0.031262874603271484 seconds
# ID 4356 has taken 0.0 seconds
# ID 4357 has taken 0.015486955642700195 seconds
# ID 4358 has taken 0.016370773315429688 seconds
# ID 4359 has taken 0.03127288818359375 seconds
# ID 4360 has taken 0.03557705879211426 seconds
# ID 4361 has taken 0.023124217987060547 seconds
# ID 4362 has taken 0.03545641899108887 seconds
# ID 4363 has taken 0.16698002815246582 seconds
# ID 4364 has taken 0.16942381858825684 seconds
# ID 4365 has taken 0.0801687240600586 seconds
# ID 4366 has taken 0.10393095016479492 seconds
# ID 4367 has taken 0.031143665313720703 seconds
# ID 4368 has taken 0.3417928218841553 seconds
# ID 4369 has taken 0.4358482360839844 seconds
# ID 4370 has taken 0.40543103218078613 seconds
# ID 4371 has taken 0.02069687843322754 seconds
# ID 4372 has taken 0.015728235244750977 seconds
# ID 4373 has taken 0.1401224136352539 seconds
# ID 4374 has taken 0.016237735748291016 seconds
# ID 4375 has taken 0.2318580150604248 seconds
# ID 4376 has taken 0.08584189414978027 seconds
# ID 4377 has taken 0.04404258728027344 seconds
# ID 4378 has taken 0.03158092498779297 seconds
# ID 4379 has taken 0.03073596954345703 seconds
# ID 4380 has taken 0.14078783988952637 seconds
# ID 4381 has taken 0.05031132698059082 seconds
# ID 4382 has taken 0.2011091709136963 seconds
# ID 4383 has taken 0.1832733154296875 seconds
# ID 4384 has taken 0.22989678382873535 seconds
# ID 4385 has taken 0.23660659790039062 seconds
# ID 4386 has taken 0.04320359230041504 seconds
# ID 4387 has taken 0.2953481674194336 seconds
# ID 4388 has taken 0.3725311756134033 seconds
# ID 4389 has taken 0.16471099853515625 seconds
# ID 4390 has taken 0.046799421310424805 seconds
# ID 4391 has taken 0.14113283157348633 seconds
# ID 4392 has taken 0.4167344570159912 seconds
# ID 4393 has taken 0.0 seconds
# ID 4394 has taken 0.8025734424591064 seconds
# ID 4395 has taken 0.08276915550231934 seconds
# ID 4396 has taken 0.016231060028076172 seconds
# ID 4397 has taken 0.0473480224609375 seconds
# ID 4398 has taken 0.2400350570678711 seconds
# ID 4399 has taken 0.09258651733398438 seconds
# ID 4400 has taken 0.002017974853515625 seconds
# ID 4401 has taken 0.0009753704071044922 seconds
# ID 4402 has taken 0.0010182857513427734 seconds
# ID 4403 has taken 0.24912500381469727 seconds
# ID 4404 has taken 0.4465510845184326 seconds
# ID 4405 has taken 0.0020885467529296875 seconds
# ID 4406 has taken 0.0965735912322998 seconds
# ID 4407 has taken 0.06612229347229004 seconds
# ID 4408 has taken 0.05752825736999512 seconds
# ID 4409 has taken 0.05796003341674805 seconds
# ID 4410 has taken 0.024929523468017578 seconds
# ID 4411 has taken 0.10026979446411133 seconds
# ID 4412 has taken 0.048877716064453125 seconds
# ID 4413 has taken 0.16768264770507812 seconds
# ID 4414 has taken 0.2159428596496582 seconds
# ID 4415 has taken 0.18395328521728516 seconds
# ID 4416 has taken 0.1956782341003418 seconds
# ID 4417 has taken 0.011721134185791016 seconds
# ID 4418 has taken 0.01899123191833496 seconds
# ID 4419 has taken 0.001049041748046875 seconds
# ID 4420 has taken 0.2890331745147705 seconds
# ID 4421 has taken 0.0562281608581543 seconds
# ID 4422 has taken 0.07603192329406738 seconds
# ID 4423 has taken 0.20375585556030273 seconds
# ID 4424 has taken 0.014472007751464844 seconds
# ID 4425 has taken 0.08711409568786621 seconds
# ID 4426 has taken 0.023819923400878906 seconds
# ID 4427 has taken 0.0031175613403320312 seconds
# ID 4428 has taken 0.0 seconds
# ID 4429 has taken 0.09998035430908203 seconds
# ID 4430 has taken 0.1251695156097412 seconds
# ID 4431 has taken 0.2286214828491211 seconds
# ID 4432 has taken 0.4131608009338379 seconds
# ID 4433 has taken 0.04331207275390625 seconds
# ID 4434 has taken 0.04253220558166504 seconds
# ID 4435 has taken 1.4035098552703857 seconds

# %% [markdown]
# The texts now have been preprocessed, so let's implement the model. To get started let's first test out a famous dataset called fetch_20newsgroups.

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset="all", remove=("headers", "footers", "quotes"))["data"]
topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(docs)

topic_model.visualize_topics().show()

# %% [markdown]
# The real deal:

# %% [markdown]
# Download german stop words

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

nltk.download("stopwords")

german_stop_words = stopwords.words("german")
specific_stop_words = ["vnd", "fuer", "vns", "ueber", "koennte", "vnsere", "vnserem", "vnser", "vnserer", "vnter", "waehrend", "vnnd", "bey", "sey", "auff", "allda", "allwo", "alsdann", "also", "demnach", "demselben", "desgleichen", "hinwiederum", "ohn", "obgleich", "obschon", "solches", "nachdem", "dergestalt", "mithin", "weswegen", "weshalb", "indem", "sodann", "wanns", "darob", "daher", "hierin", "daraus", "drum", "obgleich", "allzumal"]
german_stop_words += specific_stop_words
vect = CountVectorizer(stop_words=german_stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\raoul\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Make the documents for the model!

# %%
import sqlite3

con = sqlite3.connect("Database.db")
cur = con.cursor()

docus = []
range_index = cur.execute("SELECT COUNT(*) FROM my_data").fetchone()
for i in range(range_index[0]):
    text = cur.execute("SELECT preprocessed_text FROM my_data WHERE text_index=?", (i,)).fetchone()
    docus.append(text[0])

# %% [markdown]
# Now let's train the model!

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

sentence_transformer = SentenceTransformer("distiluse-base-multilingual-cased-v2")

topic_model = BERTopic(language="multilingual", verbose=True, low_memory=True, vectorizer_model=vect, embedding_model=sentence_transformer)
topics, probs = topic_model.fit_transform(docus)
# Out:
# 2024-12-14 10:53:19,859 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 139/139 [12:52<00:00,  5.56s/it]
# 2024-12-14 11:07:06,756 - BERTopic - Embedding - Completed ✓
# 2024-12-14 11:07:06,758 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-14 11:07:30,077 - BERTopic - Dimensionality - Completed ✓
# 2024-12-14 11:07:30,078 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-14 11:07:30,340 - BERTopic - Cluster - Completed ✓
# 2024-12-14 11:07:30,356 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-14 11:11:10,058 - BERTopic - Representation - Completed ✓

# %% [markdown]
# ***Now, there are a lot of ways in which you can visualize the outcomes***

# %% [markdown]
# Intertopic connectedness:

# %%
topic_model.visualize_topics().show()

# %% [markdown]
# Barchart:

# %%
topic_model.visualize_barchart()

# %%
embeddings = sentence_transformer.encode(docus, show_progress_bar=True)
# Out:
# Batches: 100%|██████████| 139/139 [14:43<00:00,  6.35s/it]

# %%
topic_model.visualize_heatmap()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 topic_model.visualize_heatmap()
#
# NameError: name 'topic_model' is not defined
